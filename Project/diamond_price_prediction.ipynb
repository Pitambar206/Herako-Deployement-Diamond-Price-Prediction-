# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\purna\Documents\diamonds.csv')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df = df.reindex(columns=['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z', 'price'])
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
#  9   price    53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df= df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              carat         depth         table             x             y  \
# count  53794.00000  53794.000000  53794.000000  53794.000000  53794.000000
# mean       0.79778     61.748080     57.458109      5.731214      5.734653
# std        0.47339      1.429909      2.233679      1.120695      1.141209
# min        0.20000     43.000000     43.000000      0.000000      0.000000
# 25%        0.40000     61.000000     56.000000      4.710000      4.720000
# 50%        0.70000     61.800000     57.000000      5.700000      5.710000
# 75%        1.04000     62.500000     59.000000      6.540000      6.540000
# max        5.01000     79.000000     95.000000     10.740000     58.900000
#
#                   z         price
# count  53794.000000  53794.000000
# mean       3.538714   3933.065082
# std        0.705037   3988.114460
# min        0.000000    326.000000
# 25%        2.910000    951.000000
# 50%        3.530000   2401.000000
# 75%        4.030000   5326.750000
# ...

# %%
df['carat'].hist()

# %%
df['depth'].hist()

# %%
df['price'].hist()

# %%
df_numeric = df.select_dtypes(include=['float64', 'int64'])
df_numeric.head()
# Out:
#    carat  depth  table     x     y     z  price
# 0   0.23   61.5   55.0  3.95  3.98  2.43    326
# 1   0.21   59.8   61.0  3.89  3.84  2.31    326
# 2   0.23   56.9   65.0  4.05  4.07  2.31    327
# 3   0.29   62.4   58.0  4.20  4.23  2.63    334
# 4   0.31   63.3   58.0  4.34  4.35  2.75    335

# %%
plt.figure(figsize=(15, 10))
sns.pairplot(df_numeric)
plt.show()

# %%
corr = df_numeric.corr()
corr
# Out:
#           carat     depth     table         x         y         z     price
# carat  1.000000  0.027861  0.181091  0.975380  0.951908  0.953542  0.921548
# depth  0.027861  1.000000 -0.297669 -0.025348 -0.029389  0.094757 -0.011048
# table  0.181091 -0.297669  1.000000  0.194855  0.183231  0.150270  0.126566
# x      0.975380 -0.025348  0.194855  1.000000  0.974592  0.970686  0.884504
# y      0.951908 -0.029389  0.183231  0.974592  1.000000  0.951844  0.865395
# z      0.953542  0.094757  0.150270  0.970686  0.951844  1.000000  0.861208
# price  0.921548 -0.011048  0.126566  0.884504  0.865395  0.861208  1.000000

# %%
plt.figure(figsize=(16,8))

# heatmap
sns.heatmap(corr, annot=True)
plt.show()

# %%
X = df[['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z']]
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size= 0.75, random_state= 0)

# %%
X_train
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 38685   0.30      Ideal     F    VVS1   61.1   55.0  4.36  4.38  2.67
# 6026    1.00  Very Good     D     SI2   63.2   56.0  6.38  6.33  4.02
# 26499   2.01  Very Good     H     SI2   63.4   57.0  8.00  7.93  5.05
# 28444   0.31      Ideal     G    VVS2   61.5   57.0  4.32  4.36  2.67
# 16616   1.21    Premium     H     SI1   60.2   58.0  6.93  6.88  4.16
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 46028   0.57    Premium     I    VVS1   62.1   58.0  5.32  5.25  3.28
# 52561   0.70      Ideal     G     VS2   62.1   57.0  5.66  5.70  3.53
# 42745   0.51       Good     E     SI1   63.5   54.0  5.07  5.10  3.23
# 43704   0.58      Ideal     D     SI2   61.2   57.0  5.38  5.41  3.30
# 2738    0.52      Ideal     D    VVS1   62.0   57.0  5.17  5.15  3.20
#
# [40345 rows x 9 columns]

# %%
y_train
# Out:
# 38685     1041
# 6026      3965
# 26499    16111
# 28444      671
# 16616     6640
#          ...
# 46028     1728
# 52561     2536
# 42745     1343
# 43704     1436
# 2738      3247
# Name: price, Length: 40345, dtype: int64

# %%
X_test
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 28297   0.24      Ideal     I    VVS1   62.3   57.0  3.98  3.95  2.47
# 17356   1.01      Ideal     G     VS2   62.6   56.0  6.41  6.44  4.02
# 48882   0.73    Premium     J     VS1   60.2   58.0  5.87  5.82  3.52
# 19901   1.05      Ideal     D     VS2   61.0   56.0  6.54  6.61  4.01
# 44377   0.52  Very Good     G     VS1   61.8   58.0  5.19  5.16  3.20
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 23346   0.30      Ideal     G     SI2   61.9   57.0  4.28  4.31  2.66
# 25751   1.52      Ideal     G     VS2   61.4   56.0  7.39  7.47  4.56
# 9447    1.02  Very Good     F     SI1   63.0   58.0  6.36  6.40  4.02
# 13489   1.16  Very Good     H     VS2   63.0   57.0  6.64  6.66  4.19
# 42434   0.53      Ideal     D     SI2   60.4   57.0  5.26  5.30  3.19
#
# [13449 rows x 9 columns]

# %%
y_test
# Out:
# 28297      432
# 17356     6964
# 48882     2037
# 19901     8451
# 44377     1581
#          ...
# 23346      422
# 25751    14692
# 9447      4594
# 13489     5537
# 42434     1314
# Name: price, Length: 13449, dtype: int64

# %%
X_train.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
X_train_cat = X_train.select_dtypes(include=['object'])
X_train_cat
# Out:
#              cut color clarity
# 38685      Ideal     F    VVS1
# 6026   Very Good     D     SI2
# 26499  Very Good     H     SI2
# 28444      Ideal     G    VVS2
# 16616    Premium     H     SI1
# ...          ...   ...     ...
# 46028    Premium     I    VVS1
# 52561      Ideal     G     VS2
# 42745       Good     E     SI1
# 43704      Ideal     D     SI2
# 2738       Ideal     D    VVS1
#
# [40345 rows x 3 columns]

# %%
X_train_num = X_train.select_dtypes(include=['int64', 'float64'])
X_train_num
# Out:
#        carat  depth  table     x     y     z
# 38685   0.30   61.1   55.0  4.36  4.38  2.67
# 6026    1.00   63.2   56.0  6.38  6.33  4.02
# 26499   2.01   63.4   57.0  8.00  7.93  5.05
# 28444   0.31   61.5   57.0  4.32  4.36  2.67
# 16616   1.21   60.2   58.0  6.93  6.88  4.16
# ...      ...    ...    ...   ...   ...   ...
# 46028   0.57   62.1   58.0  5.32  5.25  3.28
# 52561   0.70   62.1   57.0  5.66  5.70  3.53
# 42745   0.51   63.5   54.0  5.07  5.10  3.23
# 43704   0.58   61.2   57.0  5.38  5.41  3.30
# 2738    0.52   62.0   57.0  5.17  5.15  3.20
#
# [40345 rows x 6 columns]

# %%
X_train_cat['cut'].value_counts(normalize=True)
# Out:
# Ideal        0.399058
# Premium      0.256959
# Very Good    0.223720
# Good         0.090767
# Fair         0.029496
# Name: cut, dtype: float64

# %%
X_train_cat['color'].value_counts(normalize=True)
# Out:
# G    0.208750
# E    0.182104
# F    0.177122
# H    0.153402
# D    0.126410
# I    0.100706
# J    0.051506
# Name: color, dtype: float64

# %%
X_train_cat['clarity'].value_counts(normalize=True)
# Out:
# SI1     0.242756
# VS2     0.229248
# SI2     0.168819
# VS1     0.150675
# VVS2    0.094659
# VVS1    0.067171
# IF      0.032891
# I1      0.013781
# Name: clarity, dtype: float64

# %%
X_train_cat_le = pd.DataFrame(index= X_train_cat.index)
X_train_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [38685, 6026, 26499, 28444, 16616]

# %%
X_train_cat.cut.unique()
# Out:
# array(['Ideal', 'Very Good', 'Premium', 'Fair', 'Good'], dtype=object)

# %%
cut_encoder = {'Fair' : 1, 'Good' : 2, 'Very Good' : 3, 'Ideal' : 4, 'Premium' : 5}

X_train_cat_le['cut'] = X_train_cat['cut'].apply(lambda k : cut_encoder[k])
X_train_cat_le
# Out:
#        cut
# 38685    4
# 6026     3
# 26499    3
# 28444    4
# 16616    5
# ...    ...
# 46028    5
# 52561    4
# 42745    2
# 43704    4
# 2738     4
#
# [40345 rows x 1 columns]

# %%
X_train_cat.color.unique()
# Out:
# array(['F', 'D', 'H', 'G', 'I', 'E', 'J'], dtype=object)

# %%
color_encoder = {'J':1, 'I':2, 'H':3, 'G':4, 'F':5, 'E':6, 'D':7}

X_train_cat_le['color'] = X_train_cat['color'].apply(lambda z : color_encoder[z])
X_train_cat_le
# Out:
#        cut  color
# 38685    4      5
# 6026     3      7
# 26499    3      3
# 28444    4      4
# 16616    5      3
# ...    ...    ...
# 46028    5      2
# 52561    4      4
# 42745    2      6
# 43704    4      7
# 2738     4      7
#
# [40345 rows x 2 columns]

# %%
X_train_cat.clarity.unique()
# Out:
# array(['VVS1', 'SI2', 'VVS2', 'SI1', 'I1', 'VS2', 'IF', 'VS1'],
#       dtype=object)

# %%
clarity_encoder = {'I1':1, 'SI2':2, 'SI1':3, 'VS2':4, 'VS1':5, 'VVS2':6, 'VVS1':7, 'IF':8}

X_train_cat_le['clarity'] = X_train_cat['clarity'].apply(lambda z : clarity_encoder[z])
X_train_cat_le.head()
# Out:
#        cut  color  clarity
# 38685    4      5        7
# 6026     3      7        2
# 26499    3      3        2
# 28444    4      4        6
# 16616    5      3        3

# %%
X_train_num.head()
# Out:
#        carat  depth  table     x     y     z
# 38685   0.30   61.1   55.0  4.36  4.38  2.67
# 6026    1.00   63.2   56.0  6.38  6.33  4.02
# 26499   2.01   63.4   57.0  8.00  7.93  5.05
# 28444   0.31   61.5   57.0  4.32  4.36  2.67
# 16616   1.21   60.2   58.0  6.93  6.88  4.16

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#           carat     depth     table         x         y         z
# 38685 -1.051952 -0.455192 -1.107077 -1.224342 -1.177979 -1.250507
# 6026   0.429781  1.015185 -0.657431  0.581138  0.518920  0.695929
# 26499  2.567710  1.155221 -0.207785  2.029097  1.911248  2.180987
# 28444 -1.030784 -0.175120 -0.207785 -1.260094 -1.195383 -1.250507
# 16616  0.874301 -1.085354  0.241860  1.072729  0.997533  0.897781

# %%
X_train_transformed = pd.concat([X_train_num_rescaled, X_train_cat_le], axis=1)
X_train_transformed.head()
# Out:
#           carat     depth     table         x         y         z  cut  color  \
# 38685 -1.051952 -0.455192 -1.107077 -1.224342 -1.177979 -1.250507    4      5
# 6026   0.429781  1.015185 -0.657431  0.581138  0.518920  0.695929    3      7
# 26499  2.567710  1.155221 -0.207785  2.029097  1.911248  2.180987    3      3
# 28444 -1.030784 -0.175120 -0.207785 -1.260094 -1.195383 -1.250507    4      4
# 16616  0.874301 -1.085354  0.241860  1.072729  0.997533  0.897781    5      3
#
#        clarity
# 38685        7
# 6026         2
# 26499        2
# 28444        6
# 16616        3

# %%
X_test.head()
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 28297   0.24      Ideal     I    VVS1   62.3   57.0  3.98  3.95  2.47
# 17356   1.01      Ideal     G     VS2   62.6   56.0  6.41  6.44  4.02
# 48882   0.73    Premium     J     VS1   60.2   58.0  5.87  5.82  3.52
# 19901   1.05      Ideal     D     VS2   61.0   56.0  6.54  6.61  4.01
# 44377   0.52  Very Good     G     VS1   61.8   58.0  5.19  5.16  3.20

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13449 entries, 28297 to 42434
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    13449 non-null  float64
#  1   cut      13449 non-null  object
#  2   color    13449 non-null  object
#  3   clarity  13449 non-null  object
#  4   depth    13449 non-null  float64
#  5   table    13449 non-null  float64
#  6   x        13449 non-null  float64
#  7   y        13449 non-null  float64
#  8   z        13449 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 1.0+ MB

# %%
X_test_cat = X_test.select_dtypes(include=['object'])
X_test_cat
# Out:
#              cut color clarity
# 28297      Ideal     I    VVS1
# 17356      Ideal     G     VS2
# 48882    Premium     J     VS1
# 19901      Ideal     D     VS2
# 44377  Very Good     G     VS1
# ...          ...   ...     ...
# 23346      Ideal     G     SI2
# 25751      Ideal     G     VS2
# 9447   Very Good     F     SI1
# 13489  Very Good     H     VS2
# 42434      Ideal     D     SI2
#
# [13449 rows x 3 columns]

# %%
X_test_num = X_test.select_dtypes(include=['int64', 'float64'])
X_test_num.head()
# Out:
#        carat  depth  table     x     y     z
# 28297   0.24   62.3   57.0  3.98  3.95  2.47
# 17356   1.01   62.6   56.0  6.41  6.44  4.02
# 48882   0.73   60.2   58.0  5.87  5.82  3.52
# 19901   1.05   61.0   56.0  6.54  6.61  4.01
# 44377   0.52   61.8   58.0  5.19  5.16  3.20

# %%
X_test_num_rescaled = pd.DataFrame(scaler.fit_transform(X_test_num), 
                                   columns = X_test_num.columns, 
                                   index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#           carat     depth     table         x         y         z
# 28297 -1.176305  0.388869 -0.197182 -1.558624 -1.600353 -1.453165
# 17356  0.440447  0.597937 -0.639186  0.598959  0.628860  0.646213
# 48882 -0.147463 -1.074606  0.244823  0.119496  0.073795 -0.031005
# 19901  0.524434 -0.517091 -0.639186  0.714386  0.781055  0.632669
# 44377 -0.588395  0.040423  0.244823 -0.484272 -0.517081 -0.464425

# %%
X_test_cat_le = pd.DataFrame(index = X_test_cat.index)
X_test_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [28297, 17356, 48882, 19901, 44377]

# %%
X_test_cat_le['cut'] = X_test_cat['cut'].apply(lambda z : cut_encoder[z])
X_test_cat_le['color'] = X_test_cat['color'].apply(lambda z : color_encoder[z])
X_test_cat_le['clarity'] = X_test_cat['clarity'].apply(lambda z: clarity_encoder[z])

X_test_cat_le.head()
# Out:
#        cut  color  clarity
# 28297    4      2        7
# 17356    4      4        4
# 48882    5      1        5
# 19901    4      7        4
# 44377    3      4        5

# %%
X_test_transformed = pd.concat([X_test_num_rescaled, X_test_cat_le], axis=1)
X_test_transformed
# Out:
#           carat     depth     table         x         y         z  cut  color  \
# 28297 -1.176305  0.388869 -0.197182 -1.558624 -1.600353 -1.453165    4      2
# 17356  0.440447  0.597937 -0.639186  0.598959  0.628860  0.646213    4      4
# 48882 -0.147463 -1.074606  0.244823  0.119496  0.073795 -0.031005    5      1
# 19901  0.524434 -0.517091 -0.639186  0.714386  0.781055  0.632669    4      7
# 44377 -0.588395  0.040423  0.244823 -0.484272 -0.517081 -0.464425    3      4
# ...         ...       ...       ...       ...       ...       ...  ...    ...
# 23346 -1.050324  0.110112 -0.197182 -1.292256 -1.278057 -1.195822    4      4
# 25751  1.511282 -0.238334 -0.639186  1.469096  1.550983  1.377610    4      4
# 9447   0.461443  0.876694  0.244823  0.554565  0.593049  0.646213    3      5
# 13489  0.755398  0.876694 -0.197182  0.803175  0.825818  0.876468    3      3
# 42434 -0.567398 -0.935227 -0.197182 -0.422119 -0.391744 -0.477970    4      7
#
#        clarity
# 28297        7
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_new = pd.DataFrame(scaler.fit_transform(X_train_transformed),
                           columns = X_train_transformed.columns,
                           index = X_train_transformed.index)
X_train_new.head()
# Out:
#           carat     depth     table         x         y         z       cut  \
# 38685 -1.051952 -0.455192 -1.107077 -1.224342 -1.177979 -1.250507  0.230731
# 6026   0.429781  1.015185 -0.657431  0.581138  0.518920  0.695929 -0.743712
# 26499  2.567710  1.155221 -0.207785  2.029097  1.911248  2.180987 -0.743712
# 28444 -1.030784 -0.175120 -0.207785 -1.260094 -1.195383 -1.250507  0.230731
# 16616  0.874301 -1.085354  0.241860  1.072729  0.997533  0.897781  1.205175
#
#           color   clarity
# 38685  0.346103  1.794657
# 6026   1.521781 -1.248509
# 26499 -0.829575 -1.248509
# 28444 -0.241736  1.186024
# 16616 -0.829575 -0.639876

# %%
X_test_new = pd.DataFrame(scaler.fit_transform(X_test_transformed),
                          columns = X_test_transformed.columns,
                          index = X_test_transformed.index)
X_test_new.head()
# Out:
#           carat     depth     table         x         y         z       cut  \
# 28297 -1.176305  0.388869 -0.197182 -1.558624 -1.600353 -1.453165  0.242145
# 17356  0.440447  0.597937 -0.639186  0.598959  0.628860  0.646213  0.242145
# 48882 -0.147463 -1.074606  0.244823  0.119496  0.073795 -0.031005  1.216009
# 19901  0.524434 -0.517091 -0.639186  0.714386  0.781055  0.632669  0.242145
# 44377 -0.588395  0.040423  0.244823 -0.484272 -0.517081 -0.464425 -0.731720
#
#           color   clarity
# 28297 -1.405551  1.776780
# 17356 -0.229683 -0.032374
# 48882 -1.993485  0.570677
# 19901  1.534119 -0.032374
# 44377 -0.229683  0.570677

# %%
print("X_train:",X_train_new.shape,"\nX_test:" ,X_test_new.shape,"\ny_train:",y_train.shape,"\ny_test:",y_test.shape)
# Out:
# X_train: (40345, 9)
# X_test: (13449, 9)
# y_train: (40345,)
# y_test: (13449,)

# %%
from sklearn import metrics
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor()
regressor.fit(X_train_new, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
y_pred_knn = regressor.predict(X_test_new)

# %%
temp_knn = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_knn})
temp_knn.head()
# Out:
#        Actual  Predicted
# 28297     432      584.8
# 17356    6964     6158.0
# 48882    2037     2235.8
# 19901    8451     9063.4
# 44377    1581     1669.8

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_knn)
# Out:
# 0.9640496486729266

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_knn))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred_knn))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_knn)))
# Out:
# Mean Absolute Error:  379.80913079039334
# Mean Squared Error:  573012.4242724366
# Root Mean Squared Error:  756.9758412739714

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(X_train_new, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_lr = linear_regressor.predict(X_test_new)

# %%
temp_lr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_lr})
temp_lr.head()
# Out:
#        Actual    Predicted
# 28297     432   164.028200
# 17356    6964  5458.520971
# 48882    2037  2668.529124
# 19901    8451  6888.188298
# 44377    1581  1620.580949

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_lr)
# Out:
# 0.9047996270118979

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_lr))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred_lr))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_lr)))
# Out:
# Mean Absolute Error:  808.1135772353335
# Mean Squared Error:  1517398.1478303813
# Root Mean Squared Error:  1231.8271582614102

# %%
from sklearn.tree import DecisionTreeRegressor
dt_regressor = DecisionTreeRegressor()
dt_regressor.fit(X_train_new, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
y_pred_dt = dt_regressor.predict(X_test_new)

# %%
temp_dt = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_dt})
temp_dt.head()
# Out:
#        Actual  Predicted
# 28297     432      414.0
# 17356    6964     6591.0
# 48882    2037     1998.0
# 19901    8451     9502.0
# 44377    1581     1736.0

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_dt)
# Out:
# 0.9641417197185487

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_dt))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred_dt))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt)))
# Out:
# Mean Absolute Error:  382.106848092795
# Mean Squared Error:  571544.9044538627
# Root Mean Squared Error:  756.0058891661246

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train_new, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_rf = rf_regressor.predict(X_test_new)

# %%
temp_rf = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_rf})
temp_rf.head()
# Out:
#        Actual  Predicted
# 28297     432     466.42
# 17356    6964    6438.16
# 48882    2037    2091.58
# 19901    8451    7772.31
# 44377    1581    1742.94

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_rf)
# Out:
# 0.9801278361111984

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_rf))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred_rf))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf)))
# Out:
# Mean Absolute Error:  285.7153081414562
# Mean Squared Error:  316742.29555821186
# Root Mean Squared Error:  562.7986278929719

# %%
from pickle import dump
dump(scaler,open('C:\\Users\\purna\\Desktop\\Project\\Models\\standard_scaler.pkl','wb'))

# %%
dump(regressor,open('C:\\Users\\purna\\Desktop\\Project\\Models\\knn_regressor.pkl','wb'))
dump(linear_regressor,open('C:\\Users\\purna\\Desktop\\Project\\Models\\linear.pkl','wb'))
dump(dt_regressor,open('C:\\Users\\purna\\Desktop\\Project\\Models\\dt_regressor.pkl','wb'))
dump(rf_regressor,open('C:\\Users\\purna\\Desktop\\Project\\Models\\rf_regressor.pkl','wb'))

# %%
from pickle import load
scaler=load(open('C:\\Users\\purna\\Desktop\\Project\\Models\\standard_scaler.pkl','rb'))
regressor=load(open('C:\\Users\\purna\\Desktop\\Project\\Models\\knn_regressor.pkl','rb'))
linear_regressor=load(open('C:\\Users\\purna\\Desktop\\Project\\Models\\linear.pkl','rb'))
dt_regressor=load(open('C:\\Users\\purna\\Desktop\\Project\\Models\\dt_regressor.pkl','rb'))
rf_regressor=load(open('C:\\Users\\purna\\Desktop\\Project\\Models\\rf_regressor.pkl','rb'))

# %%
def predict(carat, cut, color, clarity, depth, table, x, y, z):
    #Predicting the price of the carat
    if cut == 'Fair':
        cut = 1
    elif cut == 'Good':
        cut = 2
    elif cut == 'Very Good':
        cut = 3
    elif cut == 'Premium':
        cut = 4
    elif cut == 'Ideal':
        cut = 5

    if color == 'J':
        color = 1
    elif color == 'I':
        color = 2
    elif color == 'H':
        color = 3
    elif color == 'G':
        color = 4
    elif color == 'F':
        color = 5
    elif color == 'E':
        color = 6
    elif color == 'D':
        color = 7
    
    if clarity == 'I1':
        clarity = 1
    elif clarity == 'SI2':
        clarity = 2
    elif clarity == 'SI1':
        clarity = 3
    elif clarity == 'VS2':
        clarity = 4
    elif clarity == 'VS1':
        clarity = 5
    elif clarity == 'VVS2':
        clarity = 6
    elif clarity == 'VVS1':
        clarity = 7
    elif clarity == 'IF':
        clarity = 8

    query_point= pd.DataFrame([[carat, cut, color, clarity, depth, table, x, y, z]], columns=['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'])
    query_point_tranformed= scaler.fit_transform(query_point)
    prediction = rf_model.predict(query_point_tranformed)
    return prediction

# %% [markdown]
# cut =input('Select the CUT rate of Diamond: 💎')
# color = input('Select the COLOR rate of Diamond: 💎')
# clarity = input('Select the CLARITY rate of Diamond: 💎')
# carat = int(float(input('Carat Weight of the Diamond 💎')))
# x = int(float(input('Diamond Length (X) in mm: 💎')))
# y = int(float(input('Diamond Width (Y) in mm: 💎')))
# z = int(float(input('Diamond Height (Z) in mm: 💎')))
# depth = int(float(input('Diamond Depth Percentage: 💎')))
# table = int(float(input('Diamond Table Percentage: 💎')))

# %%
cut =input('Select the CUT rate of Diamond: 💎')
color = input('Select the COLOR rate of Diamond: 💎')
clarity = input('Select the CLARITY rate of Diamond: 💎')
carat = int(float(input('Carat Weight of the Diamond 💎')))
x = int(float(input('Diamond Length (X) in mm: 💎')))
y = int(float(input('Diamond Width (Y) in mm: 💎')))
z = int(float(input('Diamond Height (Z) in mm: 💎')))
depth = int(float(input('Diamond Depth Percentage: 💎')))
table = int(float(input('Diamond Table Percentage: 💎')))

# %%
if predict:
    price = predict(carat, cut, color, clarity, depth, table, x, y, z)
    print(f'The predicted price of the diamond is ${price[0]:.2f} USD')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-66d7ab01e52e> in <module>
#       1 if predict:
# ----> 2     price = predict(carat, cut, color, clarity, depth, table, x, y, z)
#       3     print(f'The predicted price of the diamond is ${price[0]:.2f} USD')
#
# <ipython-input-88-408432d0ba8e> in predict(carat, cut, color, clarity, depth, table, x, y, z)
#      45
#      46     query_point= pd.DataFrame([[carat, cut, color, clarity, depth, table, x, y, z]], columns=['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'])
# ---> 47     query_point_tranformed= scaler.fit_transform(query_point)
#      48     prediction = rf_model.predict(query_point_tranformed)
#      49     return prediction
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
# ...
